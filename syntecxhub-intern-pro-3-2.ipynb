# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pavansubhasht/ibm-hr-analytics-attrition-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %%
import os

path = "/kaggle/input/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset"

# List files
os.listdir(path)
# Out:
# ['WA_Fn-UseC_-HR-Employee-Attrition.csv']

# %%
import pandas as pd

file_path = "/kaggle/input/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv"

hr_data = pd.read_csv(file_path)

# Display first 10 records
hr_data.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
# Dataset shape
hr_data.shape
# Out:
# (1470, 35)

# %%
# Column names
hr_data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Dataset information
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Count missing values
hr_data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Number of duplicate rows
hr_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
attrition_rate = (hr_data['Attrition'].value_counts()['Yes'] / len(hr_data)) * 100

print("Attrition Rate:", round(attrition_rate, 2), "%")
# Out:
# Attrition Rate: 16.12 %

# %%
employee_count = len(hr_data)

print("Total Employees:", employee_count)
# Out:
# Total Employees: 1470

# %%
average_salary = hr_data['MonthlyIncome'].mean()

print("Average Monthly Income:", round(average_salary, 2))
# Out:
# Average Monthly Income: 6502.93

# %%
average_age = hr_data['YearsAtCompany'].mean()

print("Average Years at Company:", round(average_age, 2))
# Out:
# Average Years at Company: 7.01

# %%
department_attrition = pd.crosstab(
    hr_data['Department'],
    hr_data['Attrition']
)

department_attrition
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

hr_data['Attrition'].value_counts().plot(
    kind='bar'
)

plt.title("Employee Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")

plt.show()

# %%
# Salary summary statistics

hr_data['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
# Average salary by department

salary_department = hr_data.groupby('Department')['MonthlyIncome'].mean()

salary_department
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

salary_department.plot(kind='bar')

plt.title("Average Monthly Income by Department")
plt.xlabel("Department")
plt.ylabel("Average Monthly Income")

plt.xticks(rotation=45)
plt.show()

# %%
hr_data['YearsAtCompany'].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(
    hr_data['YearsAtCompany'],
    bins=10
)

plt.title("Employee Experience Distribution")
plt.xlabel("Years at Company")
plt.ylabel("Number of Employees")

plt.show()

# %%
experience_attrition = hr_data.groupby('Attrition')['YearsAtCompany'].mean()

experience_attrition
# Out:
# Attrition
# No     7.369019
# Yes    5.130802
# Name: YearsAtCompany, dtype: float64

# %%
plt.figure(figsize=(7,5))

experience_attrition.plot(kind='bar')

plt.title("Average Years at Company by Attrition")
plt.xlabel("Attrition")
plt.ylabel("Average Years")

plt.show()

# %%
salary_attrition = hr_data.groupby('Attrition')['MonthlyIncome'].mean()

salary_attrition
# Out:
# Attrition
# No     6832.739659
# Yes    4787.092827
# Name: MonthlyIncome, dtype: float64

# %%
plt.figure(figsize=(7,5))

salary_attrition.plot(kind='bar')

plt.title("Average Salary by Attrition Status")
plt.xlabel("Attrition")
plt.ylabel("Average Monthly Income")

plt.show()

# %%
jobrole_attrition = pd.crosstab(
    hr_data['JobRole'],
    hr_data['Attrition']
)

jobrole_attrition
# Out:
# Attrition                   No  Yes
# JobRole
# Healthcare Representative  122    9
# Human Resources             40   12
# Laboratory Technician      197   62
# Manager                     97    5
# Manufacturing Director     135   10
# Research Director           78    2
# Research Scientist         245   47
# Sales Executive            269   57
# Sales Representative        50   33

# %%
plt.figure(figsize=(10,5))

jobrole_attrition.plot(
    kind='bar',
    figsize=(10,5)
)

plt.title("Attrition by Job Role")
plt.xlabel("Job Role")
plt.ylabel("Number of Employees")

plt.xticks(rotation=45)

plt.show()

# %%
department_attrition = pd.crosstab(
    hr_data['Department'],
    hr_data['Attrition']
)

department_attrition
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
plt.figure(figsize=(8,5))

department_attrition.plot(
    kind='bar',
    figsize=(8,5)
)

plt.title("Attrition Across Departments")
plt.xlabel("Department")
plt.ylabel("Employees")

plt.show()

# %%
# Create numerical Attrition column

hr_data['Attrition_Numeric'] = hr_data['Attrition'].map({
    'Yes': 1,
    'No': 0
})

hr_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
# Select numerical columns

numerical_features = hr_data.select_dtypes(
    include=['int64', 'float64']
)

numerical_features.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
# ...

# %%
# Calculate correlations

correlation_matrix = numerical_features.corr()

correlation_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,10))

plt.imshow(correlation_matrix)

plt.colorbar()

plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns
)

plt.title("HR Factors Correlation Heatmap")

plt.show()

# %%
overtime_attrition = pd.crosstab(
    hr_data['OverTime'],
    hr_data['Attrition']
)

overtime_attrition
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127

# %%
plt.figure(figsize=(7,5))

overtime_attrition.plot(
    kind='bar',
    figsize=(7,5)
)

plt.title("Attrition by Overtime Status")
plt.xlabel("Overtime")
plt.ylabel("Number of Employees")

plt.show()

# %%
satisfaction_attrition = pd.crosstab(
    hr_data['JobSatisfaction'],
    hr_data['Attrition']
)

satisfaction_attrition
# Out:
# Attrition         No  Yes
# JobSatisfaction
# 1                223   66
# 2                234   46
# 3                369   73
# 4                407   52

# %%
plt.figure(figsize=(7,5))

satisfaction_attrition.plot(
    kind='bar',
    figsize=(7,5)
)

plt.title("Attrition by Job Satisfaction Level")
plt.xlabel("Job Satisfaction")
plt.ylabel("Employees")

plt.show()

# %%
worklife_attrition = pd.crosstab(
    hr_data['WorkLifeBalance'],
    hr_data['Attrition']
)

worklife_attrition
# Out:
# Attrition         No  Yes
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27

# %%
# Total Employees
total_employees = hr_data.shape[0]

print("Total Employees:", total_employees)
# Out:
# Total Employees: 1470

# %%
employees_left = hr_data[hr_data['Attrition'] == 'Yes'].shape[0]

print("Employees Left:", employees_left)
# Out:
# Employees Left: 237

# %%
employees_retained = hr_data[hr_data['Attrition'] == 'No'].shape[0]

print("Employees Retained:", employees_retained)
# Out:
# Employees Retained: 1233

# %%
attrition_rate = (employees_left / total_employees) * 100

print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 16.12%

# %%
retention_rate = (employees_retained / total_employees) * 100

print(f"Retention Rate: {retention_rate:.2f}%")
# Out:
# Retention Rate: 83.88%

# %%
average_salary = hr_data['MonthlyIncome'].mean()

print(f"Average Monthly Income: ${average_salary:.2f}")
# Out:
# Average Monthly Income: $6502.93

# %%
average_age = hr_data['Age'].mean()

print(f"Average Age: {average_age:.2f} years")
# Out:
# Average Age: 36.92 years

# %%
average_experience = hr_data['YearsAtCompany'].mean()

print(f"Average Years at Company: {average_experience:.2f}")
# Out:
# Average Years at Company: 7.01

# %%
import matplotlib.pyplot as plt

department_attrition = pd.crosstab(
    hr_data['Department'],
    hr_data['Attrition']
)

department_attrition.plot(
    kind='bar',
    figsize=(8,5)
)

plt.title("Employee Attrition by Department")
plt.xlabel("Department")
plt.ylabel("Employees")

plt.xticks(rotation=45)

plt.show()

# %%
jobrole_attrition = pd.crosstab(
    hr_data['JobRole'],
    hr_data['Attrition']
)

jobrole_attrition.plot(
    kind='bar',
    figsize=(12,6)
)

plt.title("Employee Attrition by Job Role")
plt.xlabel("Job Role")
plt.ylabel("Employees")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    hr_data['MonthlyIncome'],
    bins=20
)

plt.title("Monthly Income Distribution")
plt.xlabel("Monthly Income")
plt.ylabel("Number of Employees")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    hr_data['Age'],
    bins=15
)

plt.title("Employee Age Distribution")
plt.xlabel("Age")
plt.ylabel("Employees")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    hr_data['YearsAtCompany'],
    bins=10
)

plt.title("Years at Company Distribution")
plt.xlabel("Years")
plt.ylabel("Employees")

plt.show()

# %%
overtime_attrition = pd.crosstab(
    hr_data['OverTime'],
    hr_data['Attrition']
)

overtime_attrition.plot(
    kind='bar',
    figsize=(6,5)
)

plt.title("Overtime vs Attrition")
plt.xlabel("Overtime")
plt.ylabel("Employees")

plt.show()

# %%
satisfaction = pd.crosstab(
    hr_data['JobSatisfaction'],
    hr_data['Attrition']
)

satisfaction.plot(
    kind='bar',
    figsize=(7,5)
)

plt.title("Job Satisfaction vs Attrition")
plt.xlabel("Job Satisfaction")
plt.ylabel("Employees")

plt.show()

# %%
plt.figure(figsize=(14,10))

plt.imshow(correlation_matrix)

plt.colorbar()

plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# Key Findings:
# The organization has 1,470 employees.
# The attrition rate is attrition rate: 16.12%, while the retention rate is retention rate: 83.88%.
# Employees working overtime show a higher likelihood of leaving the company.
# Lower monthly income is associated with higher employee attrition.
# Employees with fewer years at the company tend to leave more often than long-tenured employees.
# Some job roles and departments experience higher attrition than others, indicating areas where targeted retention efforts may be beneficial.
# Job satisfaction and work-life balance appear to influence employee retention
#
# SYNTECXHUB INTERN PRO 3 (2) HR Analytics Dashboard
# BY: OZOJI CORNELIUS OGECHUKWU
